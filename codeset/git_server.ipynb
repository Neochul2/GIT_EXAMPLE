# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 9.7/9.7 MB 87.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------- ----------------- 6.8/12.3 MB 34.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 35.1 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'c:\Users\SMT09\.pyenv\pyenv-win\versions\3.12.10\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: c:\Users\SMT09\.pyenv\pyenv-win\versions\3.12.10\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
indf = pd.read_csv("./dataset/sample.txt")
indf
# Out:
#   regionid    qty
# 0      a01    100
